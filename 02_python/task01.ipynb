# %%
name = 'Zuo'
age = 29
nxt = 30

print('はじめまして、' + name + 'と申します。\n年齢は' + str(age) + '歳です。来年は' + str(nxt) + '歳になります。\nよろしくお願いします。')
# Out:
# はじめまして、Zuoと申します。
# 年齢は29歳です。来年は30歳になります。
# よろしくお願いします。
