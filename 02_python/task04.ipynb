# %%
a = input('1つ目の数: ')
b = input('2つ目の数: ')

try:
    res = float(a) / float(b)
except ValueError:
    print('エラー: 数値を入力してください')
except ZeroDivisionError:
    print('エラー: 0 で割ることはできません')
except Exception as e:
    print(e)
else:
    print(f'計算結果: {res:.2f}')
# Out:
# 計算結果: 100.00
