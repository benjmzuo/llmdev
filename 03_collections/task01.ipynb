# %%
grades = [85, 90, 78, 92, 88]
avg = sum(grades) / len(grades)

print('平均点: ' + str(avg))
print('最高点: ' + str(max(grades)))
print('最低点: ' + str(min(grades)))
print('平均以上の学生数: '+ str(len([g for g in grades if g >= avg])))
# Out:
# 平均点: 86.6
# 最高点: 92
# 最低点: 78
# 平均以上の学生数: 3
