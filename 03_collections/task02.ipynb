# %%
from collections import defaultdict

words = []
cnt = defaultdict(int)

while True:
    word = input('英単語を入力してください：')

    if not word:
        break

    words.append(word)
    for c in word:
        cnt[c] += 1

print('入力した英単語：' + str(sorted(words)))

for k, v in cnt.items():
    print(k + 'が' + str(v) + '個ありました')
# Out:
# 入力した英単語：['cat', 'dog']
# dが1個ありました
# oが1個ありました
# gが1個ありました
# cが1個ありました
# aが1個ありました
# tが1個ありました
