# %%
import urllib.request
import datetime as dt

def save_url_content(url: str):
    response = urllib.request.urlopen(url)
    html = response.read().decode("utf-8")

    filename = dt.datetime.now().strftime("%Y%m%d_%H%M%S") + ".txt"
    with open(filename, "w", encoding="utf-8") as f:
        f.write(html[:500])

    return filename

url = input("URLを入力してください: ")
file_name = save_url_content(url)
print(f"Content saved in: {file_name}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12     return filename
#      14 url = input("URLを入力してください: ")
# ---> 15 file_name = save_url_content(url)
#      16 print(f"Content saved in: {file_name}")
#
# Cell In[2], line 8, in save_url_content(url)
#       5 response = urllib.request.urlopen(url)
#       6 html = response.read().decode("utf-8")
# ----> 8 filename = dt.datetime().now().strftime("%Y%m%d_%H%M%S") + ".txt"
#       9 with open(filename, "w", encoding="utf-8") as f:
#      10     f.write(html[:500])
#
# TypeError: function missing required argument 'year' (pos 1)
